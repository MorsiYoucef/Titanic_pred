# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
sex_mapping= {'male': 1, 'female': 0}
Train_set['Sex'] = Train_set['Sex'].map(sex_mapping)
test_set['Sex'] = test_set['Sex'].map(sex_mapping)

# %%
embarked_mapping= {'S': 1, 'C': 2,'Q': 3}
Train_set['Embarked'] = Train_set['Embarked'].map(embarked_mapping)
test_set['Embarked'] = test_set['Embarked'].map(embarked_mapping)

# %%
test_set.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
mean_fare = test_set['Fare'].mean()
print(mean_fare)
# Out:
# 35.627188489208635

# %%
test_set['Fare'].fillna(test_set['Fare'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_64531/770793585.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_set['Fare'].fillna(test_set['Fare'].mean(), inplace=True)

# %%
test_set.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
test_set['Age'].fillna(test_set['Age'].mean(), inplace=True)
# Out:
# /tmp/ipykernel_64531/1301944385.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_set['Age'].fillna(test_set['Age'].mean(), inplace=True)

# %%
Train_set['Age'].fillna(test_set['Age'].mean(), inplace=True)
# Train_set.isnull().sum()
# Out:
# /tmp/ipykernel_64531/1584020128.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Train_set['Age'].fillna(test_set['Age'].mean(), inplace=True)

# %%
Train_set.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
Train_set["Embarked"] = Train_set["Embarked"].fillna(3)

# %%
test_set.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split 

drop_columns = ['Name','Ticket','Cabin']
train_simple = Train_set.drop(drop_columns, axis=1)

train_drop_columns = ['Survived', 'PassengerId']
train_simple = train_simple.drop(train_drop_columns,axis=1)

test_simple = test_set.drop(drop_columns, axis=1)

target = Train_set['Survived']
X_train, X_val, Y_train, Y_val = train_test_split(train_simple,target, test_size = 0.2, random_state = 2)

# %%
X_val.head()
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 707       1    1  42.0      0      0  26.2875       1.0
# 37        3    1  21.0      0      0   8.0500       1.0
# 615       2    0  24.0      1      2  65.0000       1.0
# 169       3    1  28.0      0      0  56.4958       1.0
# 68        3    0  17.0      4      2   7.9250       1.0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model = LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# /home/yusuf/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_val)
accuracy = accuracy_score(Y_val,y_pred)
print(accuracy)
print(test_simple)
print(target)
# Out:
# 0.7821229050279329
#      PassengerId  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0            892       3    1  34.50000      0      0    7.8292         3
# 1            893       3    0  47.00000      1      0    7.0000         1
# 2            894       2    1  62.00000      0      0    9.6875         3
# 3            895       3    1  27.00000      0      0    8.6625         1
# 4            896       3    0  22.00000      1      1   12.2875         1
# ..           ...     ...  ...       ...    ...    ...       ...       ...
# 413         1305       3    1  30.27259      0      0    8.0500         1
# 414         1306       1    0  39.00000      0      0  108.9000         2
# 415         1307       3    1  38.50000      0      0    7.2500         1
# 416         1308       3    1  30.27259      0      0    8.0500         1
# 417         1309       3    1  30.27259      1      1   22.3583         2
#
# [418 rows x 8 columns]
# 0      0
# 1      1
# 2      1
# ...

# %%
input_data = (3,1,34.50000,0,0,7.8292,3)
input_data_to_array = np.asarray(input_data)
input_data_reshaped = input_data_to_array.reshape(1,-1)
prediction = model.predict(input_data_reshaped)

if( prediction[0] == 0):
    print("unsurvived")
else:
    print("survived")
# Out:
# unsurvived
# /home/yusuf/anaconda3/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
